# %%
import pandas as pd
import numpy as np
#import matplotlib
#import matplotlib.pyplot as plt
#import plotly.express as px
#import plotly.graph_objects as go
#import seaborn as sns
import os


rossman_sales = pd.read_csv(r'..\Training datasets\train.csv')
rossman_sales.info()
print(os.getcwd())
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_2236\3548640729.py:11: DtypeWarning: Columns (0: StateHoliday) have mixed types. Specify dtype option on import or set low_memory=False.
#   rossman_sales = pd.read_csv(r'..\Training datasets\train.csv')
# <class 'pandas.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  str
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(1), str(1)
# memory usage: 79.5+ MB
# ...
